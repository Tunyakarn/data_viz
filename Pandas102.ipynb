# %% [markdown]
# <a href="https://colab.research.google.com/github/Tunyakarn/data_viz/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 

path = '/content/drive/My Drive/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path, 'pm-18-jan-20211.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-20211.csv

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1       1/12/20  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# ## .isnull()?? คือ เอาไว้เช็คว่ามีค่าว่างรึเปล่า None??

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12418  False          False  ...              False  False
# 12419  False          False  ...              False  False
# 12420  False          False  ...              False  False
# 12421  False          False  ...              False  False
# 12422  False          False  ...              False  False
#
# [12423 rows x 10 columns]

# %% [markdown]
# .any() เอาค่าความจริงมาภายในแต่ละ column มา ```OR``` กัน

# %%
data_covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# .all() เอาค่าความจริงภายในแต่ละ column มา ```AND``` กัน

# %%
data_covid.isnull().all()
# Out:
# No.                      False
# announce_date            False
# notification_date        False
# sex                      False
# age                      False
# nationality              False
# province_of_isolation    False
# province_of_onset        False
# district_of_onset        False
# risk                     False
# dtype: bool

# %%
data_covid.iloc[0,0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-655f7c695cf3> in <module>()
# ----> 1 data_covid.iloc[0,0].isnull()
#
# AttributeError: 'numpy.int64' object has no attribute 'isnull'

# %%
data_covid['No.'][0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-85eef827ab2a> in <module>()
# ----> 1 data_covid['No.'][0].isnull()
#
# AttributeError: 'numpy.int64' object has no attribute 'isnull'

# %%
data_covid.iloc[0,0]
# Out:
# 1

# %%
data_covid.iloc[:1,0].isnull()
# Out:
# 0    False
# Name: No., dtype: bool

# %% [markdown]
# ## ต่อตารางแกน X แกน Y
#
# * ต่อแกน Y คือ เพิ่ม records (เพิ่มจำนวนข้อมูล)
# * ต่อแกน X คือ เพิ่ม column (เพิ่มรายละเอียดของข้อมูล)

# %% [markdown]
# ## ต่อแกน Y ด้วยคำสั่ง pd.concat()

# %%
data_covid['province_of_onset']=='ขอนแก่น'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12418    False
# 12419    False
# 12420    False
# 12421    False
# 12422    False
# Name: province_of_onset, Length: 12423, dtype: bool

# %%
dataKK = data_covid[data_covid['province_of_onset']=='ขอนแก่น']
dataKK.head()
# Out:
#        No.  ...                                           risk
# 180    181  ...                                        สนามมวย
# 462    463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466  1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970  1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637  2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
dataUD = data_covid[data_covid['province_of_onset']=='อุดรธานี']
dataUD.head()
# Out:
#      No.  ...                                         risk
# 424  425  ...                                      สนามมวย
# 434  435  ...                                  สถานบันเทิง
# 471  472  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 883  884  ...                                  สถานบันเทิง
# 885  886  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
dataMS = data_covid[data_covid['province_of_onset']=='มหาสารคาม']
dataMS.head()
# Out:
#          No.  ...                                         risk
# 346      347  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 789      790  ...                                  สถานบันเทิง
# 6690    6691  ...                            Cluster สมุทรสาคร
# 10802  10803  ...                            Cluster สมุทรสาคร
#
# [4 rows x 10 columns]

# %%
dataMYisan = pd.concat([dataKK,dataUD,dataMS])
dataMYisan
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 424      425  ...                                        สนามมวย
# 434      435  ...                                    สถานบันเทิง
# 471      472  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 883      884  ...                                    สถานบันเทิง
# 885      886  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 941      942  ...                                    สถานบันเทิง
# 1059    1060  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 2013    2014  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 5810    5811  ...                              Cluster สมุทรสาคร
# 7433    7434  ...                                  Cluster ระยอง
# 346      347  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 789      790  ...                                    สถานบันเทิง
# 6690    6691  ...                              Cluster สมุทรสาคร
# 10802  10803  ...                              Cluster สมุทรสาคร
#
# [28 rows x 10 columns]

# %% [markdown]
# ## ต่อแกน X
#
# * จับ 2 ตารางมาต่อกันเลย (merge)
# * เลือกมาเพิ่มเฉพาะบาง column (map)

# %%
data_province = data_covid[['No.','announce_date','province_of_onset']]
data_province
# Out:
#          No. announce_date province_of_onset
# 0          1       1/12/20     กรุงเทพมหานคร
# 1          2     1/17/2020     กรุงเทพมหานคร
# 2          3     1/22/2020            นครปฐม
# 3          4     1/22/2020     กรุงเทพมหานคร
# 4          5     1/24/2020     กรุงเทพมหานคร
# ...      ...           ...               ...
# 12418  12419     1/18/2021       สมุทรปราการ
# 12419  12420     1/18/2021       สมุทรปราการ
# 12420  12421     1/18/2021            ชลบุรี
# 12421  12422     1/18/2021            ชลบุรี
# 12422  12423     1/18/2021             ระยอง
#
# [12423 rows x 3 columns]

# %%
data_human = data_covid[['No.','age','sex','nationality']]
data_human
# Out:
#          No.   age   sex nationality
# 0          1  61.0  หญิง       China
# 1          2  74.0  หญิง       China
# 2          3  73.0  หญิง    Thailand
# 3          4  68.0   ชาย       China
# 4          5  66.0  หญิง       China
# ...      ...   ...   ...         ...
# 12418  12419  28.0  หญิง    Thailand
# 12419  12420  27.0  หญิง    Thailand
# 12420  12421  10.0   ชาย    Thailand
# 12421  12422  52.0   ชาย    Thailand
# 12422  12423  51.0   ชาย    Thailand
#
# [12423 rows x 4 columns]

# %% [markdown]
# # แบบง่ายรู้ว่า 2 ตาราง record ตรงกัน

# %%
full_table = data_human.merge(data_province)
full_table.head()
# Out:
#    No.   age   sex nationality announce_date province_of_onset
# 0    1  61.0  หญิง       China       1/12/20     กรุงเทพมหานคร
# 1    2  74.0  หญิง       China     1/17/2020     กรุงเทพมหานคร
# 2    3  73.0  หญิง    Thailand     1/22/2020            นครปฐม
# 3    4  68.0   ชาย       China     1/22/2020     กรุงเทพมหานคร
# 4    5  66.0  หญิง       China     1/24/2020     กรุงเทพมหานคร

# %% [markdown]
# ## sort

# %%
data_human2 = data_human.sort_values('age') #เรียงค่าตามตัวที่เรากำหนด
data_human2
# Out:
#          No.  age   sex nationality
# 6477    6478  0.0  หญิง    Thailand
# 1987    1988  0.0   ชาย    Thailand
# 1675    1676  0.0   ชาย       Japan
# 1075    1076  0.0   ชาย    Thailand
# 300      301  0.0   ชาย    Thailand
# ...      ...  ...   ...         ...
# 12405  12406  NaN   NaN         NaN
# 12406  12407  NaN   NaN         NaN
# 12407  12408  NaN   NaN         NaN
# 12408  12409  NaN   NaN         NaN
# 12409  12410  NaN   NaN         NaN
#
# [12423 rows x 4 columns]

# %%
full_table2 = data_human2.merge(data_province)
full_table2.head()
# Out:
#     No.  age   sex nationality announce_date province_of_onset
# 0  6478  0.0  หญิง    Thailand    12/30/2020          เพชรบุรี
# 1  1988  0.0   ชาย    Thailand        4/4/20             ระยอง
# 2  1676  0.0   ชาย       Japan        4/1/20     กรุงเทพมหานคร
# 3  1076  0.0   ชาย    Thailand     3/27/2020      สุราษฎร์ธานี
# 4   301  0.0   ชาย    Thailand     3/20/2020            ภูเก็ต

# %%
data_human2_renamed = data_human2.rename(columns={'No.':'patientNumber'})
data_human2_renamed.head()
# Out:
#       patientNumber  age   sex nationality
# 6477           6478  0.0  หญิง    Thailand
# 1987           1988  0.0   ชาย    Thailand
# 1675           1676  0.0   ชาย       Japan
# 1075           1076  0.0   ชาย    Thailand
# 300             301  0.0   ชาย    Thailand

# %%
data_human2_renamed.merge(data_province) #error เพราะชื่อ column ของทั้ง 2 อันไม่ตรงกัน
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-31-ee0d027e7ef8> in <module>()
# ----> 1 data_human2_renamed.merge(data_province)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
#     646
#     647         # note this function has side effects
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1215                 if len(common_cols) == 0:
#    1216                     raise MergeError(
# -> 1217                         "No common columns to perform merge on. "
#    1218                         f"Merge options: left_on={self.left_on}, "
#    1219                         f"right_on={self.right_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
full_table3 = data_human2_renamed.merge(data_province,left_on='patientNumber',right_on='No.')
full_table3.head()
# Out:
#    patientNumber  age   sex nationality   No. announce_date province_of_onset
# 0           6478  0.0  หญิง    Thailand  6478    12/30/2020          เพชรบุรี
# 1           1988  0.0   ชาย    Thailand  1988        4/4/20             ระยอง
# 2           1676  0.0   ชาย       Japan  1676        4/1/20     กรุงเทพมหานคร
# 3           1076  0.0   ชาย    Thailand  1076     3/27/2020      สุราษฎร์ธานี
# 4            301  0.0   ชาย    Thailand   301     3/20/2020            ภูเก็ต

# %%
full_table3 = data_human2_renamed.merge(data_covid,how='left',left_on='age',right_on='age')
full_table3.head()
# Out:
#    patientNumber  ...                                          risk
# 0           6478  ...   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1           6478  ...   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2           6478  ...   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3           6478  ...   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4           6478  ...  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
#
# [5 rows x 13 columns]

# %% [markdown]
# ## map() เลือกมาเฉพาะบาง column มาแปะเพิ่มเข้าไป

# %% [markdown]
# คุณสมบัติของ pandas ก็คือเราสามารถสร้าง column ใหม่ให้ตาราง df ได้โดย
#
# df['ชื่อ column ใหม่'] = (list ที่มีจำนวนสมาชิกเท่ากับจำนวน record ของ df) #dfคือชื่อตาราง

# %%
data_human2_renamed.head()
# Out:
#       patientNumber  age   sex nationality
# 6477           6478  0.0  หญิง    Thailand
# 1987           1988  0.0   ชาย    Thailand
# 1675           1676  0.0   ชาย       Japan
# 1075           1076  0.0   ชาย    Thailand
# 300             301  0.0   ชาย    Thailand

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1       1/12/20  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_human2_renamed['detail'] = data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk'])
data_human2_renamed
# Out:
#        patientNumber  ...                                       detail
# 6477            6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1987            1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1675            1676  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075            1076  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 300              301  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...  ...                                          ...
# 12405          12406  ...                            Cluster สมุทรสาคร
# 12406          12407  ...                            Cluster สมุทรสาคร
# 12407          12408  ...                            Cluster สมุทรสาคร
# 12408          12409  ...                            Cluster สมุทรสาคร
# 12409          12410  ...                            Cluster สมุทรสาคร
#
# [12423 rows x 5 columns]

# %% [markdown]
# คุณสมบัติของ pandas ก็คือเราสามารถสร้าง column ใหม่ให้ตาราง df ได้ โดย
#
# ```df['ชื่อ column ใหม่'] = (list ที่มีจำนวนสมาชิกเท่ากับจำนวน record ของ df)```

# %%
data_human2_renamed.head()
# Out:
#       patientNumber  ...                                       detail
# 6477           6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1987           1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1675           1676  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075           1076  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 300             301  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 5 columns]

# %%
data_human2_renamed['num'] = range(data_human2_renamed.shape[0])
data_human2_renamed
# Out:
#        patientNumber  age  ...                                       detail    num
# 6477            6478  0.0  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      0
# 1987            1988  0.0  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      1
# 1675            1676  0.0  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      2
# 1075            1076  0.0  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      3
# 300              301  0.0  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      4
# ...              ...  ...  ...                                          ...    ...
# 12405          12406  NaN  ...                            Cluster สมุทรสาคร  12418
# 12406          12407  NaN  ...                            Cluster สมุทรสาคร  12419
# 12407          12408  NaN  ...                            Cluster สมุทรสาคร  12420
# 12408          12409  NaN  ...                            Cluster สมุทรสาคร  12421
# 12409          12410  NaN  ...                            Cluster สมุทรสาคร  12422
#
# [12423 rows x 6 columns]

# %%
data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk']) #.map มันจะผูกค่า 'patientNumber' กับ 'No.' เข้าด้วยกันแล้ว return list ของค่า ['risk']
# Out:
# 6477     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1987     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1675     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 300      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#                             ...
# 12405                              Cluster สมุทรสาคร
# 12406                              Cluster สมุทรสาคร
# 12407                              Cluster สมุทรสาคร
# 12408                              Cluster สมุทรสาคร
# 12409                              Cluster สมุทรสาคร
# Name: patientNumber, Length: 12423, dtype: object

# %%
data_human2_renamed['detail'] = data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk'])
data_human2_renamed
# Out:
#        patientNumber  ...                                       detail
# 6477            6478  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1987            1988  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1675            1676  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1075            1076  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 300              301  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...  ...                                          ...
# 12405          12406  ...                            Cluster สมุทรสาคร
# 12406          12407  ...                            Cluster สมุทรสาคร
# 12407          12408  ...                            Cluster สมุทรสาคร
# 12408          12409  ...                            Cluster สมุทรสาคร
# 12409          12410  ...                            Cluster สมุทรสาคร
#
# [12423 rows x 5 columns]

# %% [markdown]
# ## HW7 สร้างตารางใหม่ที่ค่าใน ```sex``` เป็น missing ทั้งหมด
# - สรุปว่าทำไม record นั้นๆถึงเป็น missing

# %%
data_covid.iloc[:,3].isnull() #เอาทุกแถว,เลือกมาแค่ sex
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12418    False
# 12419    False
# 12420    False
# 12421    False
# 12422    False
# Name: sex, Length: 12423, dtype: bool

# %%
table_sex = []
for i in data_covid.iloc[:,3].isnull():
    table_sex.append(i)
missing_sex = data_covid[table_sex]

# %%
missing_sex
# Out:
#          No. announce_date  ... district_of_onset               risk
# 4391    4392    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4392    4393    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4393    4394    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4394    4395    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# 4395    4396    12/20/2020  ...             เมือง  Cluster สมุทรสาคร
# ...      ...           ...  ...               ...                ...
# 12405  12406     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12406  12407     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12407  12408     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12408  12409     1/18/2021  ...               NaN  Cluster สมุทรสาคร
# 12409  12410     1/18/2021  ...               NaN  Cluster สมุทรสาคร
#
# [2497 rows x 10 columns]

# %% [markdown]
# **สรุป**
#
# ข้อมูลที่ค่าใน sex เป็น missing อาจเกิดจากในหนึ่งวันมีผู้ติดเชื้อเป็นจำนวนมาก ทำให้เก็บข้อมูลได้ไม่ครบ หรืออาจเกิดจากผู้ติดเชื้อเป็นชาวต่างชาติที่ยังไม่มีประวัติฐานข้อมูลที่แน่ชัด
